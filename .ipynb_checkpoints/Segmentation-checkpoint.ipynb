# %%
#imports 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("Mall_Customers.csv")

data.rename(columns={'Annual Income (k$)':'Income', 'Spending Score (1-100)':'Score'}, inplace=True)

data.drop(['CustomerID'], axis = 1, inplace=True)

data.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Income'}>],
#        [<Axes: title={'center': 'Score'}>, <Axes: >]], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
x = data['Income']
y = data['Score']
plt.scatter(x, y)
plt.xlabel('Income')
plt.ylabel('Score')
plt.show()

# %%
data.drop(['Gender'], axis = 1).corr()
# Out:
#              Age    Income     Score
# Age     1.000000 -0.012398 -0.327227
# Income -0.012398  1.000000  0.009903
# Score  -0.327227  0.009903  1.000000

# %%
male_income = data.query('Gender == "Male"')['Income']
female_income = data.query('Gender == "Female"')['Income']

# %%
plt.violinplot([male_income, female_income])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x27f27da1150>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x27f23be7190>,
#  'cmins': <matplotlib.collections.LineCollection at 0x27f29fd8e90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x27f23c4f290>}
